# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6393  3466-RITXD    Male              0      No         No      26
# 3296  2229-VWQJH  Female              0      No         No      24
# 7007  2274-XUATA    Male              1     Yes         No      72
# 2514  8922-LIEGH  Female              1      No         No      25
# 3117  9844-FELAJ  Female              1     Yes        Yes      70
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 6393          Yes               Yes     Fiber optic            Yes  ...
# 3296          Yes                No             DSL             No  ...
# 7007           No  No phone service             DSL            Yes  ...
# 2514          Yes               Yes     Fiber optic             No  ...
# 3117          Yes               Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# <h1> Data Exploration</h1>

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
d=df.drop(columns=['customerID'])

# %%
df.drop(columns=['customerID'],inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()].shape
# Out:
# (11, 20)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df1=df[df.TotalCharges!=' ']

# %%
df1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_9488\695980592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges=pd.to_numeric(df1.TotalCharges)

# %%
df1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# ...

# %%
tenure_churn_no=df1[df1.Churn=='No'].tenure

# %%
tenure_churn_yes=df1[df1.Churn=='Yes'].tenure

# %%
plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['churn=yes','churn=No'])
plt.xlabel('tenure')
plt.ylabel('Customer churn prediction')
plt.legend()
plt.show()

# %%
MonthlyCharges_churn_no=df1[df1.Churn=='No'].MonthlyCharges

# %%
MonthlyCharges_churn_yes=df1[df1.Churn=='Yes'].MonthlyCharges

# %%
plt.hist([MonthlyCharges_churn_yes,MonthlyCharges_churn_no],color=['green','red'],label=['churn=yes','churn=No'])
plt.xlabel('MonthlyCharges')
plt.ylabel('Customer churn prediction')
plt.legend()
plt.show()

# %%
MonthlyCharges_churn_no
# Out:
# 0        29.85
# 1        56.95
# 3        42.30
# 6        89.10
# 7        29.75
#          ...
# 7037     21.15
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7042    105.65
# Name: MonthlyCharges, Length: 5163, dtype: float64

# %%
def print_unique_col_value(df):
    for col in df:
        if df[col].dtypes=='object':
            print(f'{col}: {df[col].unique()}')

# %%
print_unique_col_value(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
def print_uniquef_col_value(df):
    for col in df:
        if df[col].dtypes=='float64':
            print(f'{col}: {df[col].unique()}')

# %%
print_uniquef_col_value(df1)
# Out:
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1.replace('No internet service','No',inplace=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_9488\3939576099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)

# %%
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_9488\628100714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_value(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
s='gender Partner Dependents PhoneService MultipleLines OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies PaperlessBilling Churn'
print(s.split())
# Out:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

# %%
yes_no_columns=['gender','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
# for i in yes_no_columns:
#     x=l.fit_transform(df[i])
#     print(df)

# %%
for i in yes_no_columns:
    df1[i].replace({'Yes':1,'No':0},inplace=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_9488\3259608813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[i].replace({'Yes':1,'No':0},inplace=True)

# %%
df1
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     Female              0        1           0       1             0
# 1       Male              0        0           0      34             1
# 2       Male              0        0           0       2             1
# 3       Male              0        0           0      45             0
# 4     Female              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038    Male              0        1           1      24             1
# 7039  Female              0        1           1      72             1
# 7040  Female              0        1           1      11             0
# 7041    Male              1        1           0       4             1
# 7042    Male              0        0           0      66             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
for col in df1:
    print(f'{col}:{df1[col].unique()}')
# Out:
# gender:['Female' 'Male']
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:[1 0]
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges:[29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges:[  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn:[0 1]

# %%
df1
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0     Female              0        1           0       1             0
# 1       Male              0        0           0      34             1
# 2       Male              0        0           0       2             1
# 3       Male              0        0           0      45             0
# 4     Female              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038    Male              0        1           1      24             1
# 7039  Female              0        1           1      72             1
# 7040  Female              0        1           1      11             0
# 7041    Male              1        1           0       4             1
# 7042    Male              0        0           0      66             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
df1.replace({'Male':1,'Female':0},inplace=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_9488\2487507275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace({'Male':1,'Female':0},inplace=True)

# %%
df1
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
df2=pd.get_dummies(data=df1,columns=['InternetService','Contract','PaymentMethod'])

# %%
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
df2.isnull().sum()
# Out:
# gender                                     0
# SeniorCitizen                              0
# Partner                                    0
# Dependents                                 0
# tenure                                     0
# PhoneService                               0
# MultipleLines                              0
# OnlineSecurity                             0
# OnlineBackup                               0
# DeviceProtection                           0
# TechSupport                                0
# StreamingTV                                0
# StreamingMovies                            0
# PaperlessBilling                           0
# MonthlyCharges                             0
# TotalCharges                               0
# Churn                                      0
# InternetService_DSL                        0
# InternetService_Fiber optic                0
# InternetService_No                         0
# Contract_Month-to-month                    0
# ...

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# ...

# %%
col_to_scale=['MonthlyCharges','TotalCharges','tenure']

# %%
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()

# %%
df2[col_to_scale]=m.fit_transform(df2[col_to_scale])

# %%
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0          0              0        1           0  0.000000             0
# 1          1              0        0           0  0.464789             1
# 2          1              0        0           0  0.014085             1
# 3          1              0        0           0  0.619718             0
# 4          0              0        0           0  0.014085             1
# ...      ...            ...      ...         ...       ...           ...
# 7038       1              0        1           1  0.323944             1
# 7039       0              0        1           1  1.000000             1
# 7040       0              0        1           1  0.140845             0
# 7041       1              1        1           0  0.042254             1
# 7042       1              0        0           0  0.915493             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
df2['MonthlyCharges']
# Out:
# 0       0.115423
# 1       0.385075
# 2       0.354229
# 3       0.239303
# 4       0.521891
#           ...
# 7038    0.662189
# 7039    0.845274
# 7040    0.112935
# 7041    0.558706
# 7042    0.869652
# Name: MonthlyCharges, Length: 7032, dtype: float64

# %%
for col in df2:
    print(f'{col}:{df2[col].unique()}')
# Out:
# gender:[0 1]
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# ...

# %%
from sklearn.model_selection import train_test_split
X=df2.drop(columns=['Churn'])
y=df2.Churn
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
x_train.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                     float64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# ...

# %%
x_train.shape
# Out:
# (5625, 26)

# %%
y_train.shape
# Out:
# (5625,)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='grph', histogram_freq=1)

model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4680 - accuracy: 0.7691
# Epoch 2/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.7943
# Epoch 3/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.7957
# Epoch 4/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.7993
# Epoch 5/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.7989
# Epoch 6/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4163 - accuracy: 0.8041
# Epoch 7/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8069
# Epoch 8/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8039
# Epoch 9/10
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8071
# Epoch 10/10
# ...

# %%
model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='SGD',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5865 - accuracy: 0.7204
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.7340
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.7577
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4619 - accuracy: 0.7771
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.7842
# Epoch 6/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4432 - accuracy: 0.7883
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.7895
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7904
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.7932
# Epoch 10/100
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7754
# [0.4582648277282715, 0.7754086852073669]

# %%
yp=model.predict(x_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.00534248],
#        [0.8543822 ],
#        [0.25127977],
#        [0.8152503 ],
#        [0.61691815]], dtype=float32)

# %%
y_pred = []
for i in yp:
    if i > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 1, 0, 0, 0, 1, 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1051
#            1       0.55      0.60      0.58       356
#
#     accuracy                           0.78      1407
#    macro avg       0.71      0.72      0.71      1407
# weighted avg       0.78      0.78      0.78      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()

# %%
y_test.shape
# Out:
# (1407,)

# %% [markdown]
# # Accuracy

# %%
round((862+229)/(862+229+137+179),2)
# Out:
# 0.78

# %% [markdown]
# # Precision for 0 class. i.e. Precision for customers who did not churn

# %%
round(862/(862+179),2)
# Out:
# 0.83

# %% [markdown]
# # Recall for 0 class

# %%
round(862/(862+137),2)
# Out:
# 0.86

# %%
round(229/(229+179),2)
# Out:
# 0.56
